# %% [markdown]
# <a href="https://colab.research.google.com/github/Felipezcanal/rna/blob/main/MulitLayerPerceptron_Tensorflow.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Rede Perceptron para o porblema dos Filósofos vs Compositores
#
# O problema consiste em classificar as 4 entradas de acordo com a seguinte tabela
# ![image_2022-11-28_183709251.png](data:image/png;base64,...)

# %%
import pandas as pd
import tensorflow as tf
import numpy as np
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from tensorflow.keras.activations import hard_sigmoid, sigmoid, softmax

# %%
X = [[0,0],[0,1],[1,0],[1,1]]
Y = [[0],[1],[1],[0]]

# %%
model = Sequential()
model.add(Dense(8, input_shape=(2, ), activation=sigmoid, use_bias=True))
model.add(Dense(1, activation=hard_sigmoid))

opt = tf.keras.optimizers.SGD(learning_rate=0.1)
model.compile(loss='binary_crossentropy', metrics=['accuracy'], optimizer=opt)

model.fit(
    X,
    Y,
    epochs=1000,
    batch_size=1,
    verbose=1,
    shuffle=True
)

_, accuracy = model.evaluate(X, Y)
print("%0.3f" % accuracy)
# Out:
# Epoch 1/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7219 - accuracy: 0.5000
# Epoch 2/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7214 - accuracy: 0.2500
# Epoch 3/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.7210 - accuracy: 0.5000
# Epoch 4/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7192 - accuracy: 0.5000
# Epoch 5/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7203 - accuracy: 0.0000e+00
# Epoch 6/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7190 - accuracy: 0.5000
# Epoch 7/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.7203 - accuracy: 0.2500
# Epoch 8/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7203 - accuracy: 0.5000
# Epoch 9/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7202 - accuracy: 0.2500
# Epoch 10/1000
# ...

# %%
model.predict([[0,0], [0, 1], [1, 0], [1, 1]])
# Out:
# 1/1 [==============================] - 0s 59ms/step
# array([[0.01482192],
#        [0.7160411 ],
#        [0.861072  ],
#        [0.47972074]], dtype=float32)
