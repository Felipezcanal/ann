# %% [markdown]
# <a href="https://colab.research.google.com/github/Felipezcanal/rna/blob/main/Rede_Perceptron_Tensorflow.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Rede Perceptron para o porblema dos Filósofos vs Compositores
#
# O problema consiste em classificar as 4 entradas de acordo com a seguinte tabela
# ![image_2022-11-28_183709251.png](data:image/png;base64,...)

# %%
import pandas as pd
import tensorflow as tf
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from tensorflow.keras.activations import hard_sigmoid

# %%
X = [
    [0, 0],
    [0, 1],
    [1, 0],
    [1, 1]     
]
Y = [
    [0],
    [0],
    [1],
    [1]
]

# %%
model = Sequential()
model.add(Dense(1, input_shape=(2,), kernel_initializer=tf.initializers.Ones, activation=hard_sigmoid, use_bias=True, bias_initializer='zeros'))

opt = tf.keras.optimizers.SGD(learning_rate=1)
model.compile(loss='binary_crossentropy', metrics=['accuracy'], optimizer=opt)

model.fit(X, Y, epochs=10, batch_size=25, verbose=1, shuffle=True)

_, accuracy = model.evaluate(X, Y)
print("%0.3f" % accuracy)
# Out:
# Epoch 1/10
# 1/1 [==============================] - 0s 428ms/step - loss: 0.5898 - accuracy: 0.7500
# Epoch 2/10
# 1/1 [==============================] - 0s 12ms/step - loss: 0.5454 - accuracy: 0.7500
# Epoch 3/10
# 1/1 [==============================] - 0s 9ms/step - loss: 0.5114 - accuracy: 0.7500
# Epoch 4/10
# 1/1 [==============================] - 0s 10ms/step - loss: 0.4825 - accuracy: 0.7500
# Epoch 5/10
# 1/1 [==============================] - 0s 14ms/step - loss: 0.4568 - accuracy: 0.7500
# Epoch 6/10
# 1/1 [==============================] - 0s 11ms/step - loss: 0.4333 - accuracy: 0.7500
# Epoch 7/10
# 1/1 [==============================] - 0s 15ms/step - loss: 0.4114 - accuracy: 0.7500
# Epoch 8/10
# 1/1 [==============================] - 0s 12ms/step - loss: 0.3909 - accuracy: 1.0000
# Epoch 9/10
# 1/1 [==============================] - 0s 13ms/step - loss: 0.3713 - accuracy: 1.0000
# Epoch 10/10
# ...

# %%
model.predict([[0,0], [0, 1], [1, 0], [1, 1]])
# Out:
# 1/1 [==============================] - 0s 62ms/step
# array([[0.348427  ],
#        [0.4325367 ],
#        [0.80063844],
#        [0.8847481 ]], dtype=float32)
